# %%
import pandas as pd
df = pd.read_excel('/content/Zipcode_Demos.xlsx')
df
# Out:
#                                       0          Unnamed: 1    Unnamed: 2  \
# 0                    Average Statistics                 NaN           NaN
# 1                                   NaN                   0           NaN
# 2                     JURISDICTION NAME             10005.8           NaN
# 3                    COUNT PARTICIPANTS                 9.4           NaN
# 4                          COUNT FEMALE                 4.8           NaN
# 5                        PERCENT FEMALE               0.404           NaN
# 6                            COUNT MALE                 4.6           NaN
# 7                          PERCENT MALE               0.396           NaN
# 8                  COUNT GENDER UNKNOWN                   0           NaN
# 9                PERCENT GENDER UNKNOWN                   0           NaN
# 10                   COUNT GENDER TOTAL                 9.4           NaN
# 11                 PERCENT GENDER TOTAL                  80           NaN
# ...

# %%
#print the first five rows
df.head()
# Out:
#                     0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Average Statistics        NaN        NaN        NaN        NaN        NaN
# 1                 NaN          0        NaN        NaN        NaN        NaN
# 2   JURISDICTION NAME    10005.8        NaN        NaN        NaN        NaN
# 3  COUNT PARTICIPANTS        9.4        NaN        NaN        NaN        NaN
# 4        COUNT FEMALE        4.8        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 36 Unnamed: 37  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
# ...

# %%
#print the last five rows
df.tail()
# Out:
#         0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 53  10006          6          2       0.33          4       0.67          0
# 54  10007          1          0          0          1          1          0
# 55  10009          2          0          0          2          1          0
# 56  10010          0          0          0          0          0          0
# 57  10011          3          2       0.67          1       0.33          0
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 36 Unnamed: 37 Unnamed: 38  \
# 53          0          6        100  ...           6         100           0
# 54          0          1        100  ...           1         100           1
# 55          0          2        100  ...           2         100           0
# 56          0          0          0  ...           0           0           0
# 57          0          3        100  ...           3         100           0
#
# ...

# %%
#skip initial rows
#correct column header
df = pd.read_excel('/content/Zipcode_Demos.xlsx', header=47)
df
# Out:
#    COUNT PUBLIC ASSISTANCE TOTAL                 9.4    Unnamed: 2  \
# 0              JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE
# 1                          10001                  44            22
# 2                          10002                  35            19
# 3                          10003                   1             1
# 4                          10004                   0             0
# 5                          10005                   2             2
# 6                          10006                   6             2
# 7                          10007                   1             0
# 8                          10009                   2             0
# 9                          10010                   0             0
# 10                         10011                   3             2
#
#         Unnamed: 3  Unnamed: 4    Unnamed: 5            Unnamed: 6  \
# 0   PERCENT FEMALE  COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN
# ...

# %%
#loading data using row 47 as the header
df.columns=df.iloc[47]
df= df.drop(df.index[0:48]) #drop rows from index o to 47
df
# Out:
# 47 JURISDICTION NAME COUNT PARTICIPANTS COUNT FEMALE PERCENT FEMALE  \
# 48             10001                 44           22            0.5
# 49             10002                 35           19           0.54
# 50             10003                  1            1              1
# 51             10004                  0            0              0
# 52             10005                  2            2              1
# 53             10006                  6            2           0.33
# 54             10007                  1            0              0
# 55             10009                  2            0              0
# 56             10010                  0            0              0
# 57             10011                  3            2           0.67
#
# 47 COUNT MALE PERCENT MALE COUNT GENDER UNKNOWN PERCENT GENDER UNKNOWN  \
# 48         22          0.5                    0                      0
# 49         16         0.46                    0                      0
# ...

# %%
#removing the index from column header
df.columns.name=None
df
# Out:
#    JURISDICTION NAME COUNT PARTICIPANTS COUNT FEMALE PERCENT FEMALE  \
# 48             10001                 44           22            0.5
# 49             10002                 35           19           0.54
# 50             10003                  1            1              1
# 51             10004                  0            0              0
# 52             10005                  2            2              1
# 53             10006                  6            2           0.33
# 54             10007                  1            0              0
# 55             10009                  2            0              0
# 56             10010                  0            0              0
# 57             10011                  3            2           0.67
#
#    COUNT MALE PERCENT MALE COUNT GENDER UNKNOWN PERCENT GENDER UNKNOWN  \
# 48         22          0.5                    0                      0
# 49         16         0.46                    0                      0
# ...

# %%
#rename indexes of rows as o to 11
df.index=range(10)
df
# Out:
#   JURISDICTION NAME COUNT PARTICIPANTS COUNT FEMALE PERCENT FEMALE COUNT MALE  \
# 0             10001                 44           22            0.5         22
# 1             10002                 35           19           0.54         16
# 2             10003                  1            1              1          0
# 3             10004                  0            0              0          0
# 4             10005                  2            2              1          0
# 5             10006                  6            2           0.33          4
# 6             10007                  1            0              0          1
# 7             10009                  2            0              0          2
# 8             10010                  0            0              0          0
# 9             10011                  3            2           0.67          1
#
#   PERCENT MALE COUNT GENDER UNKNOWN PERCENT GENDER UNKNOWN COUNT GENDER TOTAL  \
# ...
